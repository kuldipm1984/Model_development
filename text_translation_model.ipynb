# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import re
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.layers import Input, Dropout, Dense, BatchNormalization, Activation, concatenate, GRU, Embedding, Flatten, BatchNormalization

# %%
df = pd.read_csv("Translation.csv")
df
# Out:
#        Unnamed: 0                                            English  \
# 0               0                A cat came out from under the desk.
# 1               1            Instead of going myself, I sent a gift.
# 2               2  let them eat crack reads this graffiti in new ...
# 3               3              My father helped me with my homework.
# 4               4           Please correct me when I make a mistake.
# ...           ...                                                ...
# 12995       12995           Our house was robbed while we were away.
# 12996       12996           I would like to speak to the head nurse.
# 12997       12997                              We'll do it tomorrow.
# 12998       12998                              What's going on here?
# 12999       12999                             Please think about it.
#
#                                                   German
# 0            Eine Katze kam unter dem Schreibtisch raus.
# 1      Anstatt selbst zu gehen, habe ich ein Geschenk...
# 2      lassen sie essen Crack liest diese Graffiti in...
# 3           Mein Vater half mir bei meinen Hausaufgaben.
# 4      Bitte korrigieren Sie mich, wenn ich einen Feh...
# ...                                                  ...
# 12995    Unser Haus wurde ausgeraubt, als wir weg waren.
# 12996         Ich möchte mit der Oberschwester sprechen.
# 12997                              Wir machen es morgen.
# 12998                                  Was ist hier los?
# 12999                     Bitte denken Sie darüber nach.
#
# [13000 rows x 3 columns]

# %%
input_texts= df['English']
target_texts=df['German']
df['German'] = "<start> " + df['German'] + " <end>"

# %%
# Tokenizing input (English) sentences
input_tokenizer = Tokenizer()
input_tokenizer.fit_on_texts(input_texts)
input_sequences = input_tokenizer.texts_to_sequences(input_texts)
max_input_length = pd.Series(input_sequences).map(len).max()+1
input_sequences_padded = pad_sequences(input_sequences, maxlen=max_input_length, padding='post')

# Tokenizing output (German) sentences
target_tokenizer = Tokenizer()
target_tokenizer.fit_on_texts(target_texts)
target_sequences = target_tokenizer.texts_to_sequences(target_texts)
max_target_length = pd.Series(target_sequences).map(len).max()+1
target_sequences_padded = pad_sequences(target_sequences, maxlen=max_target_length, padding='post')

# Vocabulary sizes
input_vocab_size = len(input_tokenizer.word_index) + 1
target_vocab_size = len(target_tokenizer.word_index) + 1

# %%
import tensorflow as tf

class AttentionLayer(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads):
        super(AttentionLayer, self).__init__()
        self.num_heads = num_heads
        self.d_model = d_model

        # Multi-Head Attention layer from TensorFlow
        self.multi_head_attention = tf.keras.layers.MultiHeadAttention(num_heads=self.num_heads, key_dim=self.d_model)
        self.dense = tf.keras.layers.Dense(d_model)  # Dense layer to output the context vector

    def call(self, encoder_outputs, decoder_outputs, mask=None):
        # Multi-Head Attention expects inputs as (batch_size, seq_len, d_model)
        # Encoder outputs: (batch_size, seq_len_encoder, d_model)
        # Decoder outputs: (batch_size, seq_len_decoder, d_model)

        # Compute attention (no need to manually compute scores here)
        attention_output, attention_weights = self.multi_head_attention(
            query=decoder_outputs,  # Decoder outputs as query
            value=encoder_outputs,  # Encoder outputs as value
            key=encoder_outputs,    # Encoder outputs as key
            attention_mask=mask,    # Mask for padding, optional
            return_attention_scores=True  # Return attention weights if needed
        )

        # The output from multi-head attention is already the weighted sum of encoder outputs
        # We can optionally pass it through a dense layer for further processing
        context_vector = self.dense(attention_output)  # (batch_size, seq_len_decoder, d_model)

        return context_vector, attention_weights

# %%
from tensorflow.keras.layers import Bidirectional, LSTM, Embedding, Dense, Input, Concatenate

d_model = 25 # embed_size
num_heads = 8  # Number of attention heads

# encoder
encoder_inputs = Input(shape=(max_input_length,))
encoder_embedded = Embedding(input_vocab_size, d_model, mask_zero=True)(encoder_inputs)
encoder_lstm = LSTM(512, return_state=True, return_sequences=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedded )
encoder_states = [state_h, state_c]

# decder
decoder_inputs = Input(shape=(None,))
decoder_embedded = Embedding(target_vocab_size, d_model, mask_zero=True)(decoder_inputs)
decoder_lstm = LSTM(512, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedded, initial_state=encoder_states)

# attention_layer
attention_layer = AttentionLayer(d_model=d_model, num_heads=num_heads)
attention_outputs, attention_weights = attention_layer(encoder_outputs, decoder_outputs)

#combined layers
decoder_combined_context = Concatenate()([decoder_outputs, attention_outputs])

output_layer = Dense(target_vocab_size, activation='softmax')
outputs = output_layer(decoder_combined_context)

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'attention_layer' (of type AttentionLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 120)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_1             │ (None, None)           │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding (Embedding)     │ (None, 120, 25)        │        253,700 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ not_equal (NotEqual)      │ (None, 120)            │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_1 (Embedding)   │ (None, None, 25)       │        335,175 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm (LSTM)               │ [(None, 120, 512),     │      1,101,824 │ embedding[0][0],       │
# │                           │ (None, 512), (None,    │                │ not_equal[0][0]        │
# │                           │ 512)]                  │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_1 (LSTM)             │ [(None, None, 512),    │      1,101,824 │ embedding_1[0][0],     │
# │                           │ (None, 512), (None,    │                │ lstm[0][1], lstm[0][2] │
# │                           │ 512)]                  │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ attention_layer           │ [(None, None, 25),     │        423,537 │ lstm[0][0],            │
# │ (AttentionLayer)          │ (None, 8, None, 120)]  │                │ lstm_1[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, None, 537)      │              0 │ lstm_1[0][0],          │
# │                           │                        │                │ attention_layer[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, None, 13407)    │      7,212,966 │ concatenate[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 10,429,026 (39.78 MB)
#  Trainable params: 10,429,026 (39.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# decoder input and output data
decoder_input_data = target_sequences_padded[:, :-1]
decoder_output_data = target_sequences_padded[:, 1:]

# %%
print("Decoder input shape:", decoder_input_data.shape)
print("Decoder output shape:", decoder_output_data.shape)
# Out:
# Decoder input shape: (13000, 148)
# Decoder output shape: (13000, 148)

# %%
# Training
history = model.fit(
    [input_sequences_padded, decoder_input_data],  # Encoder input and decoder input
    decoder_output_data,                   # Decoder output
    epochs=200,
    validation_split=0.2
)
# Out:
# Epoch 1/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 74s 205ms/step - accuracy: 0.9295 - loss: 1.3616 - val_accuracy: 0.9503 - val_loss: 0.4036
# Epoch 2/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 80s 210ms/step - accuracy: 0.9491 - loss: 0.3939 - val_accuracy: 0.9504 - val_loss: 0.3835
# Epoch 3/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - accuracy: 0.9497 - loss: 0.3712 - val_accuracy: 0.9505 - val_loss: 0.3721
# Epoch 4/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 210ms/step - accuracy: 0.9508 - loss: 0.3537 - val_accuracy: 0.9512 - val_loss: 0.3666
# Epoch 5/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - accuracy: 0.9510 - loss: 0.3408 - val_accuracy: 0.9519 - val_loss: 0.3610
# Epoch 6/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 209ms/step - accuracy: 0.9512 - loss: 0.3296 - val_accuracy: 0.9519 - val_loss: 0.3567
# Epoch 7/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - accuracy: 0.9517 - loss: 0.3153 - val_accuracy: 0.9520 - val_loss: 0.3595
# Epoch 8/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 78s 196ms/step - accuracy: 0.9530 - loss: 0.2968 - val_accuracy: 0.9521 - val_loss: 0.3661
# Epoch 9/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 196ms/step - accuracy: 0.9522 - loss: 0.2917 - val_accuracy: 0.9525 - val_loss: 0.3628
# Epoch 10/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 86s 210ms/step - accuracy: 0.9522 - loss: 0.2816 - val_accuracy: 0.9536 - val_loss: 0.3503
# Epoch 11/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 64s 196ms/step - accuracy: 0.9550 - loss: 0.2549 - val_accuracy: 0.9541 - val_loss: 0.3495
# Epoch 12/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 0.9559 - loss: 0.2409 - val_accuracy: 0.9545 - val_loss: 0.3488
# Epoch 13/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 86s 210ms/step - accuracy: 0.9587 - loss: 0.2198 - val_accuracy: 0.9549 - val_loss: 0.3511
# Epoch 14/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 196ms/step - accuracy: 0.9613 - loss: 0.2004 - val_accuracy: 0.9555 - val_loss: 0.3513
# Epoch 15/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 86s 210ms/step - accuracy: 0.9615 - loss: 0.1943 - val_accuracy: 0.9560 - val_loss: 0.3516
# Epoch 16/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s
200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 210ms/step - accuracy: 0.9998 - loss: 0.0016 - val_accuracy: 0.9608 - val_loss: 0.4984
# Epoch 50/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 78s 197ms/step - accuracy: 0.9996 - loss: 0.0028 - val_accuracy: 0.9609 - val_loss: 0.4935
# Epoch 51/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 86s 210ms/step - accuracy: 0.9997 - loss: 0.0025 - val_accuracy: 0.9610 - val_loss: 0.4954
# Epoch 52/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 78s 197ms/step - accuracy: 0.9998 - loss: 0.0018 - val_accuracy: 0.9611 - val_loss: 0.4997
# Epoch 53/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 64s 196ms/step - accuracy: 0.9979 - loss: 0.0088 - val_accuracy: 0.9608 - val_loss: 0.4882
# Epoch 54/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 0.9983 - loss: 0.0078 - val_accuracy: 0.9610 - val_loss: 0.4844
# Epoch 55/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 0.9997 - loss: 0.0025 - val_accuracy: 0.9613 - val_loss: 0.4962
# Epoch 56/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 86s 210ms/step - accuracy: 1.0000 - loss: 9.1009e-04 - val_accuracy: 0.9613 - val_loss: 0.5059
# Epoch 57/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - accuracy: 1.0000 - loss: 5.9769e-04 - val_accuracy: 0.9613 - val_loss: 0.5116
# Epoch 58/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 197ms/step - accuracy: 1.0000 - loss: 4.0792e-04 - val_accuracy: 0.9613 - val_loss: 0.5182
# Epoch 59/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 1.0000 - loss: 4.7315e-04 - val_accuracy: 0.9613 - val_loss: 0.5179
# Epoch 60/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 64s 196ms/step - accuracy: 0.9999 - loss: 6.6827e-04 - val_accuracy: 0.9609 - val_loss: 0.5130
# Epoch 61/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 87s 211ms/step - accuracy: 0.9998 - loss: 0.0014 - val_accuracy: 0.9609 - val_loss: 0.5089
# Epoch 62/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 197ms/step - accuracy: 0.9995 - loss: 0.0025 - val_accuracy: 0.9609 - val_loss: 0.5107
# Epoch 63/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 64s 196ms/step - accuracy: 0.9998 - loss: 0.0017 - val_accuracy: 0.9612 - val_loss: 0.5129
# Epoch 64/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 87s 211ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9611 - val_loss: 0.5169
# Epoch 65/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 197ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9607 - val_loss: 0.5064
# Epoch 66/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 64s 196ms/step - accuracy: 0.9966 - loss: 0.0127 - val_accuracy: 0.9611 - val_loss: 0.5019
# Epoch 67/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 87s 211ms/step - accuracy: 0.9994 - loss: 0.0034 - val_accuracy: 0.9612 - val_loss: 0.5037
# Epoch 68/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 211ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9614 - val_loss: 0.5110
# Epoch 69/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 1.0000 - loss: 3.9402e-04 - val_accuracy: 0.9614 - val_loss: 0.5179
# Epoch 70/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 1.0000 - loss: 2.6938e-04 - val_accuracy: 0.9615 - val_loss: 0.5229
# Epoch 71/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 210ms/step - accuracy: 1.0000 - loss: 2.2823e-04 - val_accuracy: 0.9614 - val_loss: 0.5268
# Epoch 72/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 78s 197ms/step - accuracy: 1.0000 - loss: 2.1107e-04 - val_accuracy: 0.9615 - val_loss: 0.5275
# Epoch 73/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 210ms/step - accuracy: 1.0000 - loss: 2.0550e-04 - val_accuracy: 0.9615 - val_loss: 0.5325
# Epoch 74/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 1.0000 - loss: 1.7720e-04 - val_accuracy: 0.9615 - val_loss: 0.5350
# Epoch 75/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 1.0000 - loss: 1.8250e-04 - val_accuracy: 0.9614 - val_loss: 0.5380
# Epoch 76/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9603 - val_loss: 0.5171
# Epoch 77/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 64s 196ms/step - accuracy: 0.9961 - loss: 0.0137 - val_accuracy: 0.9609 - val_loss: 0.5025
# Epoch 78/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 210ms/step - accuracy: 0.9991 - loss: 0.0042 - val_accuracy: 0.9611 - val_loss: 0.5063
# Epoch 79/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 0.9613 - val_loss: 0.5127
# Epoch 80/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - accuracy: 1.0000 - loss: 5.0504e-04 - val_accuracy: 0.9614 - val_loss: 0.5185
# Epoch 81/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 210ms/step - accuracy: 1.0000 - loss: 2.4197e-04 - val_accuracy: 0.9614 - val_loss: 0.5254
# Epoch 82/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 210ms/step - accuracy: 1.0000 - loss: 1.8877e-04 - val_accuracy: 0.9614 - val_loss: 0.5285
# Epoch 83/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 78s 197ms/step - accuracy: 1.0000 - loss: 1.9302e-04 - val_accuracy: 0.9615 - val_loss: 0.5301
# Epoch 84/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 86s 211ms/step - accuracy: 1.0000 - loss: 1.6544e-04 - val_accuracy: 0.9615 - val_loss: 0.5325
# Epoch 85/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 1.0000 - loss: 1.5901e-04 - val_accuracy: 0.9614 - val_loss: 0.5362
# Epoch 86/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 64s 197ms/step - accuracy: 0.9999 - loss: 3.5430e-04 - val_accuracy: 0.9612 - val_loss: 0.5293
# Epoch 87/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 64s 197ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9610 - val_loss: 0.5249
# Epoch 88/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 87s 211ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.9609 - val_loss: 0.5164
# Epoch 89/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 68s 211ms/step - accuracy: 0.9978 - loss: 0.0082 - val_accuracy: 0.9612 - val_loss: 0.5152
# Epoch 90/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 78s 198ms/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9614 - val_loss: 0.5157
# Epoch 91/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 86s 211ms/step - accuracy: 0.9999 - loss: 8.4720e-04 - val_accuracy: 0.9613 - val_loss: 0.5228
# Epoch 92/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 1.0000 - loss: 3.4892e-04 - val_accuracy: 0.9615 - val_loss: 0.5278
# Epoch 93/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 77s 197ms/step - accuracy: 1.0000 - loss: 1.8210e-04 - val_accuracy: 0.9616 - val_loss: 0.5317
# Epoch 94/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 1.0000 - loss: 1.2798e-04 - val_accuracy: 0.9615 - val_loss: 0.5386
# Epoch 95/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 197ms/step - accuracy: 1.0000 - loss: 1.7655e-04 - val_accuracy: 0.9616 - val_loss: 0.5386
# Epoch 96/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 86s 211ms/step - accuracy: 1.0000 - loss: 9.1588e-05 - val_accuracy: 0.9616 - val_loss: 0.5417
# Epoch 97/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 1.0000 - loss: 1.2476e-04 - val_accuracy: 0.9615 - val_loss: 0.5449
# Epoch 98/200
# 325/325 ━━━━━━━━━━━━━━━━━━━━ 82s 211ms/step - accuracy: 1.0000 - loss: 1.1467e-04 - val_accuracy: 0.9615 - val_loss: 0.5469
# Epoch 99/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-af6bce4087db> in <cell line: 0>()
#       1 # Training
# ----> 2 history = model.fit(
#       3     [input_sequences_padded, decoder_input_data],  # Encoder input and decoder input
#       4     decoder_output_data,                   # Decoder output
#       5     epochs=200,
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     368             with epoch_iterator.catch_stop_iteration():
#     369                 for step, iterator in epoch_iterator:
# --> 370                     callbacks.on_train_batch_begin(step)
#     371                     logs = self.train_function(iterator)
#     372                     callbacks.on_train_batch_end(step, logs)
#
# /usr/local/lib/python3.11/dist-packages/keras/src/callbacks/callback_list.py in on_train_batch_begin(self, batch, logs)
#     145             callback.on_epoch_end(epoch, logs)
#     146
# --> 147     def on_train_batch_begin(self, batch, logs=None):
#     148         logs = python_utils.pythonify_logs(logs)
#     149         for callback in self.callbacks:
#
# KeyboardInterrupt:

# %%
encoder_model = tf.keras.models.Model(encoder_inputs, [encoder_outputs, state_h, state_c])
decoder_state_input_h = tf.keras.layers.Input(shape=(512,))
decoder_state_input_c = tf.keras.layers.Input(shape=(512,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
#decoder_embedded = Embedding(target_vocab_size, d_model, mask_zero=True)(decoder_inputs)
decoder_outputs, state_h, state_c = decoder_lstm(decoder_embedded, initial_state=decoder_states_inputs)

# attention layerr
attention_outputs, attention_weights = attention_layer(encoder_outputs, decoder_outputs)

# Combined
decoder_combined_context = tf.keras.layers.concatenate([decoder_outputs, attention_outputs])

decoder_outputs = output_layer(decoder_combined_context)
decoder_model = tf.keras.models.Model(
    [decoder_inputs] + decoder_states_inputs + [encoder_outputs],
    [decoder_outputs, state_h, state_c]
)

# %%
def summarize_text(input_text):
    input_seq = input_tokenizer.texts_to_sequences([input_text])
    input_seq = pad_sequences(input_seq, maxlen=max_input_length, padding='post')

    model_outputs = encoder_model.predict(input_seq)
    encoder_outputs, state_h, state_c = model_outputs

    # Initialize the decoder input with the start token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = target_tokenizer.word_index.get('<start>', 1)

    # summary
    summary_output = ''
    for _ in range(max_target_length):
        output_tokens, h, c = decoder_model.predict([target_seq] + [state_h, state_c] + [encoder_outputs])
        predicted_token = np.argmax(output_tokens[0, -1, :])
        word = target_tokenizer.index_word.get(predicted_token, '')
        if word == '<end>':
            break
        summary_output += ' ' + word
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = predicted_token
        state_h, state_c = h, c

    return summary_output.strip()

print(summarize_text("I would like to talk with my family"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# möchte mit dir meine mutter
